# %% [markdown]
# # My Jupyter Notebook on IBM Data Science Experience

# %% [markdown]
# **Flower Yang**
# Data Analyst

# %% [markdown]
# *I am interested in data science because while I was in college, I mastered several programing languages including Python and Matlb. I’ve also taken extensive courses related to finance and mathatical analysis. I’ve always had a passion for research and took enjoyment in analysis. I loved the fact that it cultivates my computational thinking and how I can integrate logic in the process of programming to creatively meet various practical needs, including problem solving and system design.*

# %% [markdown]
# ### The Below operation is to do a mathmatical computation

# %%
2+2*8
# Out:
# 18

# %% [markdown]
# ###### Table
# | Tables        | Are           | Fun  |
# | ------------- |:-------------:| -----:|
# | col 1 is      | right-aligned |  09999
# | col 2 is      | centered      |   12 |
# | animals | are cute      |    `1` |
# | col 3 | test      |    9 |

# %% [markdown]
# ###### List
# 1. apple
# 2. orange
#   * need 5 of them.
# 3. Go to Walmart
#   1. or Target
# 4. Drive.

# %% [markdown]
# **Horiztional rules**
#
# ---
#
# separation
#
# ***
#
# separation
#
# ___
#
# separation

# %% [markdown]
# ###### syntax highlighting
# ```python
# s = "Hello World from Flower"
# print s
# ```

# %% [markdown]
# ###### Hyperlink
# <a href=https://www.cognitiveclass.ai>Cognitive Class</a>. You should now see a hyperlink to https://www.cognitiveclass.ai that appears as "Cognitive Class".

# %% [markdown]
# > Blockquotes
# > sample
#
# Quote break.
#
# > My favorite quote from Milan Qundera : **"The heaviest of burdens is therefore simultaneously an image of life's most intense fulfillment."**

# %% [markdown]
# ###### IBM LOGO
# <img src=https://upload.wikimedia.org/wikipedia/commons/5/51/IBM_logo.svg >
